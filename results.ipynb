# %%
import sys

import matplotlib.pyplot as plt
import pandas as pd
import torch

sys.path.append("../scientific_plots/")

from subplot import plot_data

# %%
results = torch.load("results.pth")
labels = list(results.keys())
data = [results[key] for key in results]

# %%
for i in ["science", "ieee", "default"]:
    plot_data(data, labels, styles=[i], grid=False)

# %%
plot_data(data, labels, is_sns=True, grid=False)
